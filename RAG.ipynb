# %% [markdown]
# ### Installation

# %%
# %pip install langchain langchain-community python_dotenv
# %pip install langchain-google-genai

# %pip install pandas numpy
# %pip install streamlit

# %pip install "unstructured[all-docs]<=0.16.10"
# %pip install langchain_postgres

# %pip install redis>=4.1.0
# Out:
# Requirement already satisfied: langchain in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-community in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.4.1)
# Requirement already satisfied: python_dotenv in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiosignal>=1.1.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.26.20)
# Requirement already satisfied: greenlet!=0.4.17 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-google-genai in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.2.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-google-genai) (1.73.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-google-genai) (1.2.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-google-genai) (2.13.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.49.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (8.5.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (44.0.0)
# Requirement already satisfied: certifi in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (6.0.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.26.20)
# Requirement already satisfied: cffi>=1.12 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.16.0)
# Requirement already satisfied: pycparser in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.56.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.33.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (1.44.0)
# Requirement already satisfied: colorama in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.19.0)
# Requirement already satisfied: six>=1.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.16.0)
# Requirement already satisfied: unstructured<=0.16.10 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (0.16.10)
# Requirement already satisfied: chardet in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (7.4.3)
# Requirement already satisfied: filetype in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.2.0)
# Requirement already satisfied: python-magic in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.4.27)
# Requirement already satisfied: lxml in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (5.3.0)
# Requirement already satisfied: nltk in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (3.9.1)
# Requirement already satisfied: requests in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.33.1)
# Requirement already satisfied: beautifulsoup4 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (4.12.3)
# Requirement already satisfied: emoji in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.15.0)
# Requirement already satisfied: dataclasses-json in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.6.7)
# Requirement already satisfied: python-iso639 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2026.4.20)
# Requirement already satisfied: langdetect in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.0.9)
# Requirement already satisfied: numpy<2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.26.4)
# Requirement already satisfied: rapidfuzz in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (3.14.5)
# Requirement already satisfied: backoff in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.2.1)
# Requirement already satisfied: typing-extensions in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (4.15.0)
# Requirement already satisfied: unstructured-client in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.43.2)
# Requirement already satisfied: wrapt in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.17.0)
# Requirement already satisfied: tqdm in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (4.66.4)
# Requirement already satisfied: psutil in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (6.0.0)
# Requirement already satisfied: python-oxmsg in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.0.2)
# Requirement already satisfied: html5lib in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.1)
# Requirement already satisfied: effdet in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (0.4.1)
# Requirement already satisfied: pypdf in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (6.10.0)
# Requirement already satisfied: xlrd in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (2.0.2)
# Requirement already satisfied: python-docx>=1.1.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.2.0)
# Requirement already satisfied: google-cloud-vision in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (3.13.0)
# Requirement already satisfied: pdf2image in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.17.0)
# Requirement already satisfied: unstructured-inference==0.8.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (0.8.1)
# Requirement already satisfied: openpyxl in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (3.1.5)
# Requirement already satisfied: pdfminer.six in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (20251230)
# Requirement already satisfied: python-pptx>=1.0.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.0.2)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (0.3.15)
# Requirement already satisfied: pikepdf in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (10.5.1)
# Requirement already satisfied: networkx in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (3.3)
# Requirement already satisfied: markdown in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (3.10.2)
# Requirement already satisfied: pandas in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (2.2.3)
# Requirement already satisfied: pypandoc in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.17)
# Requirement already satisfied: onnx in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.21.0)
# Requirement already satisfied: pi-heif in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured[all-docs]<=0.16.10) (1.3.0)
# Requirement already satisfied: layoutparser in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.3.4)
# Requirement already satisfied: python-multipart in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.0.26)
# Requirement already satisfied: huggingface-hub in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.12.0)
# Requirement already satisfied: opencv-python!=4.7.0.68 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.25.0)
# Requirement already satisfied: matplotlib in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.9.1)
# Requirement already satisfied: torch in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2.4.1+cu124)
# Requirement already satisfied: timm in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.0.26)
# Requirement already satisfied: transformers>=4.25.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (5.6.2)
# Requirement already satisfied: flatbuffers in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (25.2.10)
# Requirement already satisfied: packaging in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (23.2)
# Requirement already satisfied: protobuf in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (5.29.6)
# Requirement already satisfied: Pillow>=3.3.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-pptx>=1.0.1->unstructured[all-docs]<=0.16.10) (12.2.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-pptx>=1.0.1->unstructured[all-docs]<=0.16.10) (3.2.9)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (6.0.1)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.22.2)
# Requirement already satisfied: typer in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.24.2)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.0.9)
# Requirement already satisfied: idna in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.16.0)
# Requirement already satisfied: colorama in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.0.0)
# Requirement already satisfied: torchvision in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from effdet->unstructured[all-docs]<=0.16.10) (0.19.1+cu124)
# Requirement already satisfied: pycocotools>=2.0.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from effdet->unstructured[all-docs]<=0.16.10) (2.0.11)
# Requirement already satisfied: omegaconf>=2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from effdet->unstructured[all-docs]<=0.16.10) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]<=0.16.10) (4.9.3)
# Requirement already satisfied: sympy in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.12)
# Requirement already satisfied: jinja2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.1.4)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[all-docs]<=0.16.10) (2.24.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-cloud-vision->unstructured[all-docs]<=0.16.10) (2.49.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-cloud-vision->unstructured[all-docs]<=0.16.10) (1.68.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-cloud-vision->unstructured[all-docs]<=0.16.10) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[all-docs]<=0.16.10) (1.66.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[all-docs]<=0.16.10) (1.68.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]<=0.16.10) (0.4.1)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]<=0.16.10) (44.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.26.20)
# Requirement already satisfied: cffi>=1.12 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]<=0.16.10) (1.16.0)
# Requirement already satisfied: pycparser in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]<=0.16.10) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]<=0.16.10) (0.6.1)
# Requirement already satisfied: six>=1.9 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from html5lib->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.16.0)
# Requirement already satisfied: webencodings in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from html5lib->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->torch->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2.1.5)
# Requirement already satisfied: scipy in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.14.1)
# Requirement already satisfied: iopath in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.1.10)
# Requirement already satisfied: pdfplumber in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.11.9)
# Requirement already satisfied: portalocker in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from iopath->layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2.9.0.post0)
# Requirement already satisfied: click in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (8.3.3)
# Requirement already satisfied: joblib in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.4.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from onnx->unstructured[all-docs]<=0.16.10) (0.5.1)
# Requirement already satisfied: et-xmlfile in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openpyxl->unstructured[all-docs]<=0.16.10) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas->unstructured[all-docs]<=0.16.10) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas->unstructured[all-docs]<=0.16.10) (2024.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pdfplumber->layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (5.7.1)
# Requirement already satisfied: Deprecated in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pikepdf->unstructured[all-docs]<=0.16.10) (1.2.15)
# Requirement already satisfied: pywin32>=226 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (306)
# Requirement already satisfied: olefile in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-oxmsg->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.47)
# Requirement already satisfied: mpmath>=0.19 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sympy->torch->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich>=12.3.0->typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich>=12.3.0->typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]<=0.16.10) (0.1.2)
# Requirement already satisfied: aiofiles>=25.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (25.1.0)
# Requirement already satisfied: pydantic>=2.12.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.13.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.12.5->unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.12.5->unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.12.5->unstructured-client->unstructured<=0.16.10->unstructured[all-docs]<=0.16.10) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_postgres in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.0.17)
# Requirement already satisfied: asyncpg>=0.30.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_postgres) (0.31.0)
# Requirement already satisfied: langchain-core<2.0,>=0.2.13 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_postgres) (1.2.28)
# Requirement already satisfied: numpy<3,>=1.21 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_postgres) (1.26.4)
# Requirement already satisfied: pgvector<0.4,>=0.2.5 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_postgres) (0.3.6)
# Requirement already satisfied: psycopg-pool<4,>=3.2.1 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_postgres) (3.3.0)
# Requirement already satisfied: psycopg<4,>=3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from psycopg[binary]<4,>=3->langchain_postgres) (3.3.3)
# Requirement already satisfied: sqlalchemy<3,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]<3,>=2->langchain_postgres) (2.0.31)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (2.13.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0,>=0.2.13->langchain_postgres) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=0.2.13->langchain_postgres) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (1.0.9)
# Requirement already satisfied: idna in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (0.16.0)
# Requirement already satisfied: tzdata in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from psycopg<4,>=3->psycopg[binary]<4,>=3->langchain_postgres) (2024.1)
# Requirement already satisfied: psycopg-binary==3.3.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from psycopg[binary]<4,>=3->langchain_postgres) (3.3.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain_postgres) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain_postgres) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain_postgres) (0.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy<3,>=2->sqlalchemy[asyncio]<3,>=2->langchain_postgres) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain_postgres) (1.26.20)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Libraries

# %%
from unstructured.partition.pdf import partition_pdf
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough, RunnableLambda

from langchain_postgres.vectorstores import PGVector
from database import COLLECTION_NAME, CONNECTION_STRING
from langchain_community.storage import RedisStore
from langchain.schema.document import Document
from langchain.retrievers.multi_vector import MultiVectorRetriever
from pathlib import Path
from IPython.display import display, HTML, Markdown
from base64 import b64decode
import os, hashlib, shutil, uuid, json, time
import torch, redis
import logging

# Initialize Redis client
client = redis.Redis(host="localhost", port=6379, db=0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from unstructured.partition.pdf import partition_pdf
#       2 from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
#       3 from langchain_core.messages import SystemMessage, HumanMessage
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\unstructured\partition\pdf.py:74
#      68 from unstructured.partition.pdf_image.form_extraction import run_form_extraction
#      69 from unstructured.partition.pdf_image.pdf_image_utils import (
#      70     check_element_types_to_extract,
#      71     convert_pdf_to_images,
#      72     save_elements,
#      73 )
# ---> 74 from unstructured.partition.pdf_image.pdfminer_processing import (
#      75     check_annotations_within_element,
#      76     clean_pdfminer_inner_elements,
#      77     get_links_in_element,
#      78     get_uris,
#      79     get_words_from_obj,
#      80     map_bbox_and_index,
#      81     merge_inferred_with_extracted_layout,
#      82 )
#      83 from unstructured.partition.pdf_image.pdfminer_utils import (
#      84     open_pdfminer_pages_generator,
#      85     rect_to_bbox,
#      86 )
#      87 from unstructured.partition.strategies import determine_pdf_or_image_strategy, validate_strategy
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\unstructured\partition\pdf_image\pdfminer_processing.py:14
#      12 from unstructured.documents.elements import CoordinatesMetadata
#      13 from unstructured.partition.pdf_image.pdf_image_utils import remove_control_characters
# ---> 14 from unstructured.partition.pdf_image.pdfminer_utils import (
#      15     extract_image_objects,
#      16     extract_text_objects,
#      17     open_pdfminer_pages_generator,
#      18     rect_to_bbox,
#      19 )
#      20 from unstructured.partition.utils.config import env_config
#      21 from unstructured.partition.utils.constants import SORT_MODE_BASIC, Source
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\unstructured\partition\pdf_image\pdfminer_utils.py:9
#       7 from pdfminer.pdfinterp import PDFPageInterpreter, PDFResourceManager
#       8 from pdfminer.pdfpage import PDFPage
# ----> 9 from pdfminer.pdfparser import PSSyntaxError
#      11 from unstructured.logger import logger
#      12 from unstructured.utils import requires_dependencies
#
# ImportError: cannot import name 'PSSyntaxError' from 'pdfminer.pdfparser' (C:\Users\chris\AppData\Local\Programs\Python\Python311\Lib\site-packages\pdfminer\pdfparser.py)

# %%
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY", "")

# %%
FILE_PATH = Path("../temp_727515528-Group-2-ITI-Consensus-Report-Prosthodontics-and-implant-dentistry.pdf")

# %% [markdown]
# ### Data Loading

# %% [markdown]
# Partition tables and text into chunks

# %%
def data_loading():

    raw_pdf_elements = partition_pdf(
        filename=FILE_PATH,
      
        infer_table_structure=True,
        strategy="fast",

        extract_image_block_types=["Image"],
        extract_image_block_to_payload=True,

        chunking_strategy="by_title",
        mode='elements',
        max_characters=10000,
        new_after_n_chars=5000,
        combine_text_under_n_chars=2000,
        image_output_dir_path="data/",
    )
    return raw_pdf_elements

# %%
pdf_elements = data_loading()

# %%
pdf_elements

# %%
# tables[0].metadata.to_dict()

# %%
tables = [element.metadata.text_as_html for element in pdf_elements if 'Table' in str(type(element))]
text = [element.text for element in pdf_elements if 'CompositeElement' in str(type(element))]

# %%
tables

# %%
text

# %%
display(HTML(tables[0]))

# %% [markdown]
# ### Summarize the Data

# %%
# Summarize extracted text and tables using LLM
def summarize_text_and_tables(text, tables):
    logging.info("Ready to summarize data with LLM")
    prompt_text = """You are an assistant tasked with summarizing text and tables. \
    
                    You are to give a concise summary of the table or text and do nothing else. 
                    Table or text chunk: {element} """
    prompt = ChatPromptTemplate.from_template(prompt_text)
    model = ChatGoogleGenerativeAI(temperature=0.6, model="gemini-2.5-flash")
    summarize_chain = {"element": RunnablePassthrough()} | prompt | model | StrOutputParser()
    logging.info(f"{model} done with summarization")
    return {
        "text": summarize_chain.batch(text, {"max_concurrency": 5}),
        "table": summarize_chain.batch(tables, {"max_concurrency": 5})
    }

# %%
data_summary = summarize_text_and_tables(text, tables)

# %%
data_summary

# %%
text_summary = data_summary['text']

# %%
tables_summary = data_summary['table']

# %% [markdown]
# ### Initialize Retriever

# %%
def initialize_retriever():

    store = RedisStore(client=client)
    id_key = "doc_id"
    vectorstore = PGVector(
            embeddings=GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001"),
            collection_name=COLLECTION_NAME,
            connection=CONNECTION_STRING,
            use_jsonb=True,
            )
    retrieval_loader = MultiVectorRetriever(vectorstore=vectorstore, docstore=store, id_key="doc_id")
    return retrieval_loader

# %%
load_retriever = initialize_retriever()

# %% [markdown]
# ### Add Summary to vectorstore & Raw data to RedisStore

# %%
# Store text, tables, and their summaries in the retriever

def store_docs_in_retriever(text, text_summary, table, table_summary, retriever):
    """Store text and table documents along with their summaries in the retriever."""

    def add_documents_to_retriever(documents, summaries, retriever, id_key = "doc_id"):
        """Helper function to add documents and their summaries to the retriever."""
        if not summaries:
            return None, []

        doc_ids = [str(uuid.uuid4()) for _ in documents]
        summary_docs = [
            Document(page_content=summary, metadata={id_key: doc_ids[i]})
            for i, summary in enumerate(summaries)
        ]

        retriever.vectorstore.add_documents(summary_docs, ids=doc_ids)
        retriever.docstore.mset(list(zip(doc_ids, documents)))     

# Add text, table, and image summaries to the retriever
    add_documents_to_retriever(text, text_summary, retriever)
    add_documents_to_retriever(table, table_summary, retriever)
    return retriever

# %%
retriever  = store_docs_in_retriever(text, text_summary, tables,  tables_summary, load_retriever)

# %%
query = "What is the comparison of the composition of red meat and vegetarian protein sources"

# %%
docs = retriever.invoke(query)

# %%
docs
# Out:
# [b'1. Folate values from US data [39]; all other values from NUTTAB 2006 [38]\n\n10\n\nTable 6. Percentage of male adult recommended dietary intake (RDI) or adequate intake (AI)\n\nprovided by 100g of lean red meat and some vegetarian protein sources',
#  b'2) Nutrient composition of red meat\n\nRed meat contains high biological value protein and important micronutrients that are needed for good health throughout life. It also contains a range of fats, including essential omega-3 polyunsaturated fats. Recent analyses have shown that there has been a significant trend to leaner cuts of meat over the past two decades [3]. While the nutritional composition will vary somewhat according to breed, feeding regimen, season and meat cut, in general lean red meat has a low fat content, is moderate in cholesterol and rich in protein and many essential vitamins and minerals.\n\n1\n\n2.1 Nutrient composition of beef, veal, lamb and mutton\n\nTable 1 presents the typical nutrient composition of samples of fat-trimmed Australian red meat, based on recent analyses of national retail samples [4-6] and compares this to the new Australian recommended dietary intakes [7]. While there are some differences between the four meats, in general lean red meat is a particularly good source of protein, niacin, vitamin B6, vitamin B12, phosphorus, zinc and iron, with 100g providing more than 25% RDI of these nutrients. It also provides more than 10% RDI of riboflavin, pantothenic acid, and selenium. Of the four meats, mutton is particularly nutrient dense, and the richest source of thiamin, vitamins B6 and B12, phosphorus, iron and copper.\n\nProtein and amino acids\n\nRaw red muscle meat contains around 20-25g protein/100g. Cooked red meat contains 28- 36g/100g, because the water content decreases and nutrients become more concentrated during cooking. The protein is highly digestible, around 94% compared to the digestibility of 78% in beans and 86% in whole wheat [8]. Protein from meat provides all essential amino acids (lysine, threonine, methionine, phenylalanine, tryptophan, leucine, isoleucine, valine) and has no limiting amino acids. Protein Digestibility Corrected Amino Acid Score (PDCAAS) is a method of evaluating the protein quality, with a maximum possible score of 1.0. Animal meats like beef have a score of approximately 0.9, compared to values of 0.5-0.7 for most plant foods [9]. The amino acid glutamic acid/glutamine is present in meat in the highest amounts (16.5%), followed by arginine, alanine, and aspartic acid.',
#  b'Table 1. Nutrient composition (per 100g) of lean red meat [4-6]',
#  b'University of Wollongong\n\nResearch Online\n\nFaculty of Health and Behavioural Sciences - Papers (Archive)\n\nFaculty of Science, Medicine and Health\n\nSeptember 2007\n\nNutritional composition of red meat\n\nP. G. Williams University of Wollongong, peterw@uow.edu.au\n\nFollow this and additional works at: https://ro.uow.edu.au/hbspapers\n\nPart of the Arts and Humanities Commons, Life Sciences Commons, Medicine and Health Sciences Commons, and the Social and Behavioral Sciences Commons\n\nRecommended Citation\n\nWilliams, P. G.: Nutritional composition of red meat 2007. https://ro.uow.edu.au/hbspapers/48\n\nResearch Online is the open access institutional repository for the University of Wollongong. For further information contact the UOW Library: research-pubs@uow.edu.au\n\nNutritional composition of red meat\n\nAbstract\n\nLean red meats are: \xe2\x80\xa2 An excellent source of high biological value protein, vitamin B12, niacin, vitamin B6, iron, zinc and phosphorus \xe2\x80\xa2 A source of long-chain omega-3 polyunsaturated fats, riboflavin, pantothenic acid, selenium and possibly also vitamin D \xe2\x80\xa2 Mostly low in fat and sodium \xe2\x80\xa2 Sources of a range of endogenous antioxidants and other bioactive substances including taurine, carnitine, carnosine, ubiquinone, glutathione and creatine.\n\nKeywords\n\nred meat, nutrients, beef, lamb, mutton, veal\n\nDisciplines\n\nArts and Humanities | Life Sciences | Medicine and Health Sciences | Social and Behavioral Sciences\n\nPublication Details\n\nThis article was originally published as: Williams, PG, Nutritional composition of red meat, Nutrition & Dietetics, 2007, 64(Suppl 4), S113-S119. The definitive version is available at www.blackwell-synergy.com. Nutrition & Dietetics is the official journal of the Dietitians Association of Australia. Copyright 2007 Blackwell Publishing.\n\nThis journal article is available at Research Online: https://ro.uow.edu.au/hbspapers/48\n\nThe Nutritional Composition of Red Meat\n\nAssoc Prof Peter Williams PhD FDAA\n\nSmart Foods Centre, University of Wollongong']

# %% [markdown]
# ### RAG Pipeline

# %% [markdown]
# #### Parse the retriever output

# %%
def parse_retriver_output(data):
    parsed_elements = []
    for element in data:
        # Decode bytes to string if necessary
        if isinstance(element, bytes):
            element = element.decode("utf-8")
        
        parsed_elements.append(element)
    
    return parsed_elements

# %% [markdown]
# #### Chat with the LLM using retrieved context

# %%
def chat_with_llm():

    prompt_text = """
                You are an AI Assistant tasked with understanding detailed
                information from text and tables. You are to answer the question based on the 
                context provided to you. You must not go beyond the context given to you.
                
                Context:
                {context}

                Question:
                {question}
                """

    prompt = ChatPromptTemplate.from_template(prompt_text)
    model = ChatGoogleGenerativeAI(temperature=0.6, model="gemini-2.5-flash")

    rag_chain = {
       "context": retriever | RunnableLambda(parse_retriver_output), "question": RunnablePassthrough(),
        } | RunnablePassthrough().assign(
# %%
print(response['response'])
# Out:
# The nutrient composition per 100g of lean red meat for beef, veal, lamb, and mutton is as follows:
#
# | Nutrient              | Beef  | Veal  | Lamb  | Mutton |
# |----------------------|-------|-------|-------|--------|
# | Moisture (g)         | 73.1  | 74.8  | 72.9  | 73.2   |
# | Protein (g)          | 23.2  | 24.8  | 21.9  | 21.5   |
# | Fat (g)              | 2.8   | 1.5   | 4.7   | 4.0    |
# | Energy (kJ)          | 498   | 477   | 546   | 514    |
# | Cholesterol (mg)     | 50    | 51    | 66    | 66     |
# | Thiamin (mg)         | 0.04  | 0.06  | 0.12  | 0.16   |
# | Riboflavin (mg)      | 0.18  | 0.20  | 0.23  | 0.25   |
# | Niacin (mg)          | 5.0   | 16.0  | 5.2   | 8.0    |
# | Vitamin B6 (mg)      | 0.52  | 0.80  | 0.10  | 0.80   |
# | Vitamin B12 (µg)     | 2.5   | 1.6   | 0.96  | 2.8    |
# | Pantothenic acid (mg) | 0.35  | 1.50  | 0.74  | 1.33   |
# | Vitamin A (µg)       | <5    | <5    | 8.6   | 7.8    |
# | Beta-carotene (µg)   | 10    | <5    | <5    | <5     |
# | Alpha-tocopherol (mg) | 0.63  | 0.50  | 0.44  | 0.20   |
# | Sodium (mg)          | 51    | 51    | 69    | 71     |
# | Potassium (mg)       | 363   | 362   | 344   | 365    |
# | Calcium (mg)         | 4.5   | 6.5   | 7.2   | 6.6    |
# | Iron (mg)            | 1.8   | 1.1   | 2.0   | 3.3    |
# | Zinc (mg)            | 4.6   | 4.2   | 4.5   | 3.9    |
# | Magnesium (mg)       | 25    | 26    | 28    | 28     |
# | Phosphorus (mg)      | 215   | 260   | 194   | 290    |
# | Copper (mg)          | 0.12  | 0.08  | 0.12  | 0.22   |
#
# This table summarizes the nutrient composition for each type of meat.

# %%
response = rag_chain.invoke("What is the nutrient composition of organ meats")

# %%
print(response['response'])
# Out:
# The nutrient composition of organ meats (specifically liver, kidney, heart, brain, and tripe from beef and lamb) includes the following key points:
#
# 1. **Vitamin B12**: All organ meats (except tripe) are extremely rich in vitamin B12, providing more than 100% of the Recommended Daily Intake (RDI) in 100g.
#
# 2. **Liver**:
#    - Rich source of protein, iron, zinc, riboflavin, niacin, vitamin A, and folate.
#
# 3. **Kidney**:
#    - Rich in protein, thiamin, riboflavin, iron, and a source of folate.
#
# 4. **Heart**:
#    - A good source of iron and zinc, but not as rich as liver and kidney.
#
# 5. **Brain and Tripe**:
#    - Not particularly good sources of vitamins or minerals.
#
# 6. **Cholesterol**:
#    - All organ meats are high in cholesterol, especially brains.
#
# 7. **Sodium**:
#    - Generally low in sodium across all organ meats.
#
# 8. **Liver Warning**:
#    - Liver is such a rich source of retinol (vitamin A) that large amounts are not recommended during pregnancy.
#
# These points indicate that organ meats are nutrient-dense, particularly in terms of certain vitamins and minerals, making them valuable in a diet.

# %%
response = rag_chain.invoke("What is Meat?")
